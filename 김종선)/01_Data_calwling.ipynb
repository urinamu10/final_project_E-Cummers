# %% [markdown]
# ## 크롤링은 공개 X

# %% [markdown]
# ---

# %% [markdown]
# ### <center> 지그재그 크롤링

# %% [markdown]
# ---

# %% [markdown]
# #### <CENTER> 1-1 product_id 추출

# %% [markdown]
# #### <CENTER> 1-2 카테고리 5개 크롤링

# %% [markdown]
# ---

# %% [markdown]
# ### <CENTER> 2. 29CM 크롤링

# %% [markdown]
# ---

# %% [markdown]
# #### <center> product_id 추출 (리뷰 많은 순)

# %% [markdown]
# #### <center> 2-2 29cm 리뷰 크롤링

# %% [markdown]
# ---

# %% [markdown]
# ### <center> 3. Weather

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ### <CENTER> 4. 네이버 검색 데이터랩

# %% [markdown]
# ---
